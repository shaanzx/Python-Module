# %%
import requests

response = requests.get("https://api.github.com/events")
print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %%
import requests

response = requests.get("https://api.github.com/events")
if response.status_code == 200 : 
    print("Success")
else:
    print(f"Faild to retrive data. Status code {response.status_code}")
# Out:
# Success

# %%
import requests

response = requests.get("https://api.github.com/events")
print(response.headers)
print(type(response.headers))
print(response.headers['server'])
# Out:
# {'Date': 'Wed, 23 Jul 2025 03:57:33 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept,Accept-Encoding, Accept, X-Requested-With', 'ETag': 'W/"e9b654eb5a66775471cde5ad17e4d0da21e6885d76593e942406b88f1cdca555"', 'Last-Modified': 'Wed, 23 Jul 2025 03:52:33 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'x-github-api-version-selected': '2022-11-28', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Used, X-RateLimit-Resource, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type, X-GitHub-SSO, X-GitHub-Request-Id, Deprecation, Sunset', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; prel
# ...

# %%
import requests

response = requests.get("https://api.github.com/events")
print(response.text)
print(type(response.text))
print(response.text[:100]) #This line prints the first 100 characters
# Out:
# [{"id":"52423922344","type":"ReleaseEvent","actor":{"id":203043444,"login":"suwei8","display_login":"suwei8","gravatar_id":"","url":"https://api.github.com/users/suwei8","avatar_url":"https://avatars.githubusercontent.com/u/203043444?"},"repo":{"id":1016386165,"name":"suwei8/LottoAI3_HitMatrix_date","url":"https://api.github.com/repos/suwei8/LottoAI3_HitMatrix_date"},"payload":{"action":"published","release":{"url":"https://api.github.com/repos/suwei8/LottoAI3_HitMatrix_date/releases/234422218","assets_url":"https://api.github.com/repos/suwei8/LottoAI3_HitMatrix_date/releases/234422218/assets","upload_url":"https://uploads.github.com/repos/suwei8/LottoAI3_HitMatrix_date/releases/234422218/assets{?name,label}","html_url":"https://github.com/suwei8/LottoAI3_HitMatrix_date/releases/tag/p5_baiwei_sha3","id":234422218,"author":{"login":"suwei8","id":203043444,"node_id":"U_kgDODBoydA","avatar_url":"https://avatars.githubusercontent.com/u/203043444?v=4","gravatar_id":"","url":"https://api.g
# ...

# %%
import requests

response = requests.get("https://api.github.com/events")
data = response.json()

print(data)
print(type(data))
# Out:
# [{'id': '52424073195', 'type': 'PushEvent', 'actor': {'id': 203202005, 'login': 'dailyEV', 'display_login': 'dailyEV', 'gravatar_id': '', 'url': 'https://api.github.com/users/dailyEV', 'avatar_url': 'https://avatars.githubusercontent.com/u/203202005?'}, 'repo': {'id': 1018239582, 'name': 'dailyEV/feed', 'url': 'https://api.github.com/repos/dailyEV/feed'}, 'payload': {'repository_id': 1018239582, 'push_id': 25665836790, 'size': 1, 'distinct_size': 1, 'ref': 'refs/heads/master', 'head': '59d0a35c1854f7730d0664e790c7e1b449c15583', 'before': '4707bb7198e77762e5261fd53d6b23e229670221', 'commits': [{'sha': '59d0a35c1854f7730d0664e790c7e1b449c15583', 'author': {'email': 'zhecht7@gmail.com', 'name': 'Zack Hecht'}, 'message': 'test', 'distinct': True, 'url': 'https://api.github.com/repos/dailyEV/feed/commits/59d0a35c1854f7730d0664e790c7e1b449c15583'}]}, 'public': True, 'created_at': '2025-07-23T04:05:02Z'}, {'id': '52424073208', 'type': 'WatchEvent', 'actor': {'id': 5168415, 'login': 'coryjo'
# ...

# %%
import requests

url = "https://api.github.com/events"

response = requests.get(url)

if response.status_code == 200:
    print("Success")
    if 'application/json' in response.headers.get('Content-Type', ''):
        data = response.json()
        print(data)
    
    print(response.text)
else:
    print(f"Error while fetching {response.status_code}")
# Out:
# Success
# ...

# %%
import requests

url = 'https://httpbin.org/post'
data = {'username' : 'user', 'password' : 'pass'}

response = requests.post(url, data=data)

if response.status_code == 200:
    print('Data retrive successfully done!')
    print(response.text)
    print(response.url)
else:
    print(f'Faild to login {response.status_code}')
# Out:
# Data retrive successfully done!
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "pass",
#     "username": "user"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68806a8d-26d8ebbb1a7d242d0895156e"
#   },
#   "json": null,
#   "origin": "103.21.164.208",
#   "url": "https://httpbin.org/post"
# }
#
# https://httpbin.org/post

# %%
# URL Parameters

import requests

url = 'https://jsonplaceholder.typicode.com/posts'
parms = {'userId' : 1, 'id' : 2}

response = requests.get(url, params=parms)
if response.status_code == 200:
    print('Successfully Done!')
    print(response.text)
    print(response.url)
else: 
    print('Data feching error!')
# Out:
# Successfully Done!
# [
#   {
#     "userId": 1,
#     "id": 2,
#     "title": "qui est esse",
#     "body": "est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#   }
# ]
# https://jsonplaceholder.typicode.com/posts?userId=1&id=2

# %%
import requests

url = 'https://httpbin.org/get'
username = 'user'
password = 'pass'

response = requests.get(url, auth=(username, password))
if response.status_code == 200:
    print('Authenticate success!')
    print(response.text)
else:
    print(f'Data feching error! {response.status_code}')
# Out:
# Authenticate success!
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Authorization": "Basic dXNlcjpwYXNz",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-68807169-163ede2b52eda49818e30ca6"
#   },
#   "origin": "103.21.164.208",
#   "url": "https://httpbin.org/get"
# }
